# %% [markdown]
# # Quiz Capítulo 6.
#
# * **Abril Serna Juan Pablo**

# %% [markdown]
# ## Pregunta 1.
#
# ¿Cuál de las siguientes afirmaciones sobre el aprendizaje es incorrecta?

# %% [markdown]
# 1. El aprendizaje supervisado utiliza tanto datos de entrada como datos de aprendizaje dado un resultado, pero el aprendizaje no supervisado se utiliza en forma de aprendizaje que utiliza solo datos de entrada sin datos de aprendizaje.
#
# 2. Se puede decir que el aprendizaje no supervisado es un método de aprendizaje que informa el problema pero no da la respuesta.
#
# 3. Se pueden utilizar el análisis de agrupamiento jerárquico y el agrupamiento de K-means para la agrupación, como algoritmo de aprendizaje no supervisado.
#
# 4. En agrupaciones con K-means es fácil determinar el número inicial de agrupaciones y de interpretar los resultados.

# %% [markdown]
# <font color=red>[Respuesta]</font>
# <h2>La afirmacion incorrecta es la 4, debido a que agrupar k-means no es una tarea sencilla, debido a que su dificultad radica en la complegidad del problema y la calidad de los datos </h2>

# %% [markdown]
# ## Pregunta 2.
#
# ¿Cuál de las siguientes afirmaciones sobre la agrupación (clustering) es incorrecta?

# %% [markdown]
# 1. La técnica de agrupamiento más utilizada es K-Means.
# 2. La agrupación jerárquica se decide después de agrupar sin determinar el número de grupos.
# 3. El algoritmo de agrupamiento jerárquico tiene K-medoids.
# 4. La agrupación es una técnica que asigna y analiza grupos en función de la similitud o diferencia entre cada entidad.

# %% [markdown]
# <font color=red>[Respuesta]</font>
# <h2>La afirmación incorrecta es la 3 debido a que el algoritmo de agrupamiento jerárquico no está intrínsecamente asociado con el concepto de K-medoids. ya que K-medoids es una variante del algoritmo K-means que se utiliza para agrupar datos en grupos predefinidos</h2>

# %% [markdown]
# ## Pregunta 3.
#
# El algoritmo EM pertenece al algoritmo codicioso (greedy algorithm). Por favor explique el motivo.

# %% [markdown]
# <font color=red>[Respuesta]</font>
# <h3> El algoritmo EM no pertenece al algoritmo codicioso (greedy algorithm) debido a el algoritmo codicioso toma las decisiones localmente para buscar la solucion optima en cada momento, para encontrar la solucion global más optima.
# mientras que EM se usa para encontrar parametros en modelos de probabilidad cuando los datos son desconocidos o se encuentran ocultos, EM tiene dos pasos el Expectation que es el que encuentra los parametros cuando estan ocultos o desconocidos mientras que Maximización se encarga de actualizar los datos con lo obtenido de el paso anterior Expectation</h3>

# %% [markdown]
# ## Pregunta 4.
#
# Escribe tres o más ejemplos de algoritmo de agrupamiento. (ej. Análisis de datos)

# %% [markdown]
# <font color=red>[Respuesta]</font>
# <h3>K-Means</h3>
# <h3> agrupamiento jerarquico </h3>
# <h3> Fuzzy C-Means</h3>

# %% [markdown]
# ## Pregunta 5.
#
# Explica los dos métodos para elegir el número óptimo de grupos cuando se utilizan K-means. Describe cómo encontrar el número óptimo de conjuntos o agrupaciones utilizando los dos métodos.

# %% [markdown]
# <font color=red>[Respuesta]</font>
# <h3> Metodó del codo: se ejectua el algoritmo de k-means en un rango de valores entre 1 a un grupo que sea razonable, despues se calcula la suma de los cuadrados de las distancias y despues se hace el grafico de k contra la inercia para buscar el punto de la curva donde se comienza a aplanarse. </h3>
# <h3>Metodo de la silueta: el coeficiente tiene un valor entre -1 y 1, si tiene un valor mayor es porque está bien clasificado mientras si es bajo está mal, además, cada valor de k se calcula el coeficiente promedio de todos los putnos de los datos y el numero óptimo es el que maximiza el coeficiente de silueta promedio</h3>

# %% [markdown]
# ## Pregunta 6.
#
# Agrupa y visualiza datos de muestra del siguiente código utilizando los algoritmos K-Means, Aggregate Clustering y DBSCan.
#
# Para K-Means y Aggregate Clustering, establece el número de agrupaciones a 3.

# %%
from sklearn.datasets import make_blobs, make_moons
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

X, label = make_blobs(n_samples=300, n_features=2, centers=3, cluster_std=5, random_state=123)
plt.scatter(X[:,0], X[:,1], c=label, alpha=0.7)
plt.title('Dataset #1 : Original')
plt.show()

# %% [markdown]
# <font color=red>[Respuesta]</font>

# %% [markdown]
# <h1>K-MEANS
# </h1>

# %%
kmeans = KMeans(n_clusters=3, n_init=10)
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
kmeans_labels = kmeans.labels_

# %%
plt.scatter(X[:,0], X[:,1], c=kmeans_labels, alpha=0.7)
plt.title('K-Means Clustering')
plt.show()

# %% [markdown]
# <h3>Agglomerative Clustering</h3>

# %%
agg_clustering = AgglomerativeClustering(n_clusters=3)
agg_labels = agg_clustering.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=agg_labels, alpha=0.7)
plt.title('Agglomerative Clustering')
plt.show()

# %% [markdown]
# <h3>DBSCAN</h3>

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=dbscan_labels, alpha=0.7)
plt.title('DBSCAN Clustering')
plt.show()
